# %% [markdown]
# <a href="https://colab.research.google.com/github/anikatahsin2658/AI-lab-3/blob/main/AI_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
courses = []
choice = 'random'

def line():
    print('---------------------------------------------')

def show_menu():
    line()
    print('Options')
    line()
    print('1. Add new course')
    print('2. Remove a course')
    print('3. View all courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice!= '4':
    choice = show_menu()
    if choice == '1':
        item = input('Course Name: ')
        courses.append(item)
        print('Course ',item,' added')
    elif choice =='2':
        item = input('Which course do you want to remove or unroll? ')
        if item in courses:
            courses.remove(item)
            print('Unrolled from ',item,' course')
        else:
            print('You are not enrolled in this course')
    elif choice == '3':
        print('List of all enrolled courses:')
        for item in courses:
            print(item)
    elif choice == '4':
        print('Bye')
    else:
        print('Please enter one of 1,2,3 or 4')
# Out:
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: Artificial Intelligence
# Please enter one of 1,2,3 or 4
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Computer Networks
# Course  Computer Networks  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Database Management System
# Course  Database Management System  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 3
# List of all enrolled courses:
# Computer Networks
# Database Management System
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Data Structure
# Course  Data Structure  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: Software Project V
# Please enter one of 1,2,3 or 4
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 2
# Which course do you want to remove or unroll? Data Structure
# Unrolled from  Data Structure  course
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 3
# List of all enrolled courses:
# Computer Networks
# Database Management System
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 1
# Course Name: Artificial Intelligence
# Course  Artificial Intelligence  added
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 3
# List of all enrolled courses:
# Computer Networks
# Database Management System
# Artificial Intelligence
# ---------------------------------------------
# Options
# ---------------------------------------------
# 1. Add new course
# 2. Remove a course
# 3. View all courses
# 4. Exit
# ---------------------------------------------
# Enter your choice: 4
# Bye
